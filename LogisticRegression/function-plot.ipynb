# %% [markdown]
# 导入 numpy 和 matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 绘制 Sigmoid 函数

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.linspace(-20, 20, 400)
y = sigmoid(x)

plt.figure(figsize=(16, 8))
plt.ylim(-0.1, 1.1)
plt.plot(x, y, label='sigmoid', color='blue')
plt.axhline(y=0.5, color='red', linestyle='--', label="y = 0.5")

plt.title("Sigmoid Function")
plt.xlabel("x")
plt.ylabel("sigmoid(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# 绘制 Sigmoid 的损失函数

# %%
x1 = np.linspace(0.002, 1, 400)
x2 = np.linspace(0, 0.998, 400)
y1 = -np.log(x1)
y2 = -np.log(1 - x2)

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(x1, y1)
plt.title('if y = 1')
plt.xlabel(r'$h_\theta(x)$')
plt.ylabel('L(x)')

plt.subplot(1, 2, 2)
plt.plot(x2, y2)
plt.title('if y = 0')
plt.xlabel(r'$h_\theta(x)$')
plt.ylabel('L(x)')
plt.show()
