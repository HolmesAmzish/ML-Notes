# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
model.train(
    data='data.yaml',
    epochs=20,
    batch=16,
    name='yolov8n-plantdoc',
    project='yolo-plantdoc'
)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7933MiB)
# ...
